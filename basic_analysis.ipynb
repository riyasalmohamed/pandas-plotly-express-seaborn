# %%
import pandas as pd 
import plotly.express as px
import seaborn as sns
df=pd.read_csv("D:Riyas/datasets/archive/speed_price_att.csv")

# %%
df.shape
# Out:
# (432303, 26)

# %%
df.columns
# Out:
# Index(['address_full', 'incorporated_place', 'major_city', 'state', 'lat',
#        'lon', 'block_group', 'collection_datetime', 'provider', 'speed_down',
#        'speed_up', 'speed_unit', 'price', 'technology', 'package',
#        'fastest_speed_down', 'fastest_speed_price', 'fn', 'redlining_grade',
#        'race_perc_non_white', 'income_lmi', 'ppl_per_sq_mile', 'n_providers',
#        'income_dollars_below_median', 'internet_perc_broadband',
#        'median_household_income'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of                                          address_full incorporated_place  \
# 0       2406 Country Club Ave NW, Huntsville AL 35816    Huntsville city
# 1             1902 Oglesby Dr NW, Huntsville AL 35816    Huntsville city
# 2           2312 Cardinal Ave NW, Huntsville AL 35816    Huntsville city
# 3             1903 Oglesby Dr NW, Huntsville AL 35816    Huntsville city
# 4         1905 Canterbury Cir NW, Huntsville AL 35816    Huntsville city
# ...                                               ...                ...
# 432298              304 S 82nd St, Milwaukee WI 53214     Milwaukee city
# 432299              146 S 81st St, Milwaukee WI 53214     Milwaukee city
# 432300              145 S 77th St, Milwaukee WI 53214     Milwaukee city
# 432301              151 N 80th St, Milwaukee WI 53213     Milwaukee city
# 432302     194 S Honey Creek Pkwy, Milwaukee WI 53214     Milwaukee city
#
#         major_city state        lat        lon   block_group  \
# 0       huntsville    AL  34.745179 -86.606806   10890007022
# 1       huntsville    AL  34.747563 -86.607140   10890007022
# 2       huntsville    AL  34.746504 -86.605884   10890007022
# 3       huntsville    AL  34.747759 -86.607675   10890007022
# 4       huntsville    AL  34.748585 -86.605223   10890007022
# ...            ...   ...        ...        ...           ...
# 432298   milwaukee    WI  43.028712 -88.014866  550790127001
# 432299   milwaukee    WI  43.030284 -88.013114  550790127001
# 432300   milwaukee    WI  43.030459 -88.008985  550790127001
# 432301   milwaukee    WI  43.032435 -88.013174  550790127001
# 432302   milwaukee    WI  43.029370 -88.014126  550790127001
#
#         collection_datetime provider  speed_down  ...  fastest_speed_price  \
# 0                1650310200     AT&T       0.768  ...                 55.0
# 1                1650310229     AT&T       5.000  ...                 55.0
# 2                1650310203     AT&T       0.768  ...                 55.0
# 3                1650310195     AT&T       5.000  ...                 55.0
# 4                1650310196     AT&T     300.000  ...                180.0
# ...                     ...      ...         ...  ...                  ...
# 432298           1650286871     AT&T     300.000  ...                 80.0
# 432299           1650286872     AT&T     300.000  ...                 80.0
# 432300           1650286907     AT&T     300.000  ...                 80.0
# 432301           1650286889     AT&T      50.000  ...                 55.0
# 432302           1650286878     AT&T     300.000  ...                 80.0
#
#                                                        fn  redlining_grade  \
# 0       ../data/intermediary/isp/att/huntsville/010890...              NaN
# 1       ../data/intermediary/isp/att/huntsville/010890...              NaN
# 2       ../data/intermediary/isp/att/huntsville/010890...              NaN
# 3       ../data/intermediary/isp/att/huntsville/010890...              NaN
# 4       ../data/intermediary/isp/att/huntsville/010890...              NaN
# ...                                                   ...              ...
# 432298  ../data/intermediary/isp/att/milwaukee/5507901...              NaN
# 432299  ../data/intermediary/isp/att/milwaukee/5507901...              NaN
# 432300  ../data/intermediary/isp/att/milwaukee/5507901...                D
# 432301  ../data/intermediary/isp/att/milwaukee/5507901...              NaN
# 432302  ../data/intermediary/isp/att/milwaukee/5507901...              NaN
#
#        race_perc_non_white income_lmi  ppl_per_sq_mile  n_providers  \
# 0                 0.475059   0.381744       512.090069          4.0
# 1                 0.475059   0.381744       512.090069          4.0
# 2                 0.475059   0.381744       512.090069          4.0
# 3                 0.475059   0.381744       512.090069          4.0
# 4                 0.475059   0.381744       512.090069          4.0
# ...                    ...        ...              ...          ...
# 432298            0.145038   1.546388      1163.711163          2.0
# 432299            0.145038   1.546388      1163.711163          2.0
# 432300            0.145038   1.546388      1163.711163          2.0
# 432301            0.145038   1.546388      1163.711163          2.0
# 432302            0.145038   1.546388      1163.711163          2.0
#
#        income_dollars_below_median internet_perc_broadband  \
# 0                          35091.0                0.527881
# 1                          35091.0                0.527881
# 2                          35091.0                0.527881
# 3                          35091.0                0.527881
# 4                          35091.0                0.527881
# ...                            ...                     ...
# 432298                    -23563.0                0.911591
# 432299                    -23563.0                0.911591
# 432300                    -23563.0                0.911591
# 432301                    -23563.0                0.911591
# 432302                    -23563.0                0.911591
#
#         median_household_income
# 0                         21667
# 1                         21667
# 2                         21667
# 3                         21667
# 4                         21667
# ...                         ...
# 432298                    66688
# 432299                    66688
# 432300                    66688
# 432301                    66688
# 432302                    66688
#
# [432303 rows x 26 columns]>

# %%
df.head()
# Out:
#                                     address_full incorporated_place  \
# 0  2406 Country Club Ave NW, Huntsville AL 35816    Huntsville city
# 1        1902 Oglesby Dr NW, Huntsville AL 35816    Huntsville city
# 2      2312 Cardinal Ave NW, Huntsville AL 35816    Huntsville city
# 3        1903 Oglesby Dr NW, Huntsville AL 35816    Huntsville city
# 4    1905 Canterbury Cir NW, Huntsville AL 35816    Huntsville city
#
#    major_city state        lat        lon  block_group  collection_datetime  \
# 0  huntsville    AL  34.745179 -86.606806  10890007022           1650310200
# 1  huntsville    AL  34.747563 -86.607140  10890007022           1650310229
# 2  huntsville    AL  34.746504 -86.605884  10890007022           1650310203
# 3  huntsville    AL  34.747759 -86.607675  10890007022           1650310195
# 4  huntsville    AL  34.748585 -86.605223  10890007022           1650310196
#
#   provider  speed_down  ...  fastest_speed_price  \
# 0     AT&T       0.768  ...                 55.0
# 1     AT&T       5.000  ...                 55.0
# 2     AT&T       0.768  ...                 55.0
# 3     AT&T       5.000  ...                 55.0
# 4     AT&T     300.000  ...                180.0
#
#                                                   fn  redlining_grade  \
# 0  ../data/intermediary/isp/att/huntsville/010890...              NaN
# 1  ../data/intermediary/isp/att/huntsville/010890...              NaN
# 2  ../data/intermediary/isp/att/huntsville/010890...              NaN
# 3  ../data/intermediary/isp/att/huntsville/010890...              NaN
# 4  ../data/intermediary/isp/att/huntsville/010890...              NaN
#
#   race_perc_non_white income_lmi  ppl_per_sq_mile  n_providers  \
# 0            0.475059   0.381744       512.090069          4.0
# 1            0.475059   0.381744       512.090069          4.0
# 2            0.475059   0.381744       512.090069          4.0
# 3            0.475059   0.381744       512.090069          4.0
# 4            0.475059   0.381744       512.090069          4.0
#
#   income_dollars_below_median internet_perc_broadband  median_household_income
# 0                     35091.0                0.527881                    21667
# 1                     35091.0                0.527881                    21667
# 2                     35091.0                0.527881                    21667
# 3                     35091.0                0.527881                    21667
# 4                     35091.0                0.527881                    21667
#
# [5 rows x 26 columns]

# %%
df.isnull().values.any()
# Out:
# True
